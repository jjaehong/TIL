# %% [markdown]
# ## APP VS WEB

# %% [markdown]
# #### 1. WEB
#
# 1. 장점
#
#     - 브라우저만 있으면 어디서든 접속 가능
#     - 웹 페이지가 업데이트된 후 배포 속도가 빠름
#     - 플랫폼 환경에 제약이 없음
#
# 2. 단점
#
#     - 속도가 느림
#     - UI사용성이 앱보다는 좋지 않음
#     - 연결하기 위해서 URL을 입력해야 한다.

# %% [markdown]
# #### 2. APP
#
# 1. 장점
#
#     - 앱 마켓 사용가능 (다양한 수익 창출 가능)
#     - 알람, 주소록, 카메라, GPS등의 스마트폰 기능을     사용할 수 있음
#     - 서비스 실행이 편함 (아이콘 클릭으로 서비스    시작 가능)
#     - 스마트폰에 최적화 되어있어 속도가 빠름
#     - UI사용성이 스마트폰에 최적화되어 있음
#
# 2. 단점
#
#     - 마켓에 등록하기 위해 개발자 등록을 해야 함
#     - 사용자가 앱을 다운받아야 하는 불편함
#     - IOS, AOS 모두 개발 해야 함
#     - 앱이 수정되면 마켓에 새로 배포해야 함 (배포까지의 시간이 오래 걸림)
#     - 사용자가 사용하는 디바이스 OS에 따라 버전을   관리해야 함
#
# ------
#
# 정해진 자원과 한정된 기간 내에 최대한 완성도를 높이기 위해
#
# → 공통의 목표를 정하기!
#
# → 핵심 기능 명확하게 파악하기!
#
# → 팀의 역량 객관화하기!
