# %% [markdown]
# ## 면접시 싸피 경험을 이야기 할 때
#
# 1. 자기 주도 능력(신기술에 대한 적응 능력을 가짐)
# 2. 협업 프로젝트 경험(나와 맞지 않는 팀원을 만나도 좋은 결과를 만들어 낼 수 있는 능력)
# 3. 실무에서 다루는 환경 경험(git, jira, aws, DBMS)
# 4. 수상경력(플젝)
# 5. 팀리딩 경험(팀장의 경우)
# 6. 4차산업 도메인 관련 포트폴리오 보유(빅데이터, 인공지능, 블록체인, 모빌리티)
# 7. SSAFY라는 표현은 면접관을 배려하지 않는 표현(삼성청년소프트웨어 아카데미, 이하 싸피라고해야함)
# 8. 실무기술 사용경험(CICD, Docker, SPA, Kubernetes, WebRTC, 깃, 지라 등)
# 9. 뻔한 웹 프로젝트 이야기는 본인을 어필하기 어렵다.
# 10. 프로젝트 과정 중 겪었던 어려움과 극복방법,
# 11.  readme 작성 중요함! 신경써서 작성함(깃헙, 프로젝트)
#
# 13. readme가 중요한 이유(깃헙 readme)
# - 이 사람의 일머리를 알 수 있는 가장 쉬운 방법
# - 개발 업무의 정리를 잘하는 사람과 일하고 싶어함
# - 스스로 학습을 하는 발전형 인재임을 보여줄 수 있는 곳
