# %% [markdown]
# ## 2. Vue syntax

# %% [markdown]
# #### 1. Template Syntax
#
# - DOM을 기본 구성 요소 인스턴스의 데이터에 **선언적으로 바인딩(Vue 인스턴스와 DOM을 연결)**할 수 있는 **HTML 기반 템플릿 구문(확장된 문법 제공)**을 사용
#
# 1. 종류 : Text Interpolation, Raw HTML, Attribute Bindings, JavaScript Expressions
#
#
#     1. Text Interpolation( {{}} )
#
#         ![이미지](../이미지/text%20interpolation.PNG)
#
#         - 데이터 바인딩의 가장 기본적인 형태 : {{}}
#         - {{ }} 은 msg 속성 값으로 대체됨
#         - msg 속성이 변경될 때마다 업데이트 됨(동적)
#
#
#     2. Raw HTML
#
#         ![이미지](../이미지/rawhtml.PNG)
#
#         - 콧수염 구문({{}})은 span style도 일반 텍스트로 해석함.
#         - 그래서 v-html을 사용해야함
#
#
#     3. Attribute Bindings
#
#         ![이미지](../이미지/attribute%20bindings.PNG)
#
#         - 콧수염 구문을 HTML 속성 내에서 사용하도록 v-bind를 사용하여 묶음
#         - **HTML의 id 속성 값 ==(동기화, bind) dynamicld 속성**
#         - 바인딩 값이 null이나 undefine의 경우 렌더링 요소에서 제거됨
#
#
#     4. JavaScript Expressions
#
#         ![이미지](../이미지/jsexpressions.PNG)
#
#         - number 속성 + 1 표시
#         - ? == if : ok 속성이 true면 YES, false면 NO
#         - ''기준으로 잘랐다가 뒤집었다가 다시 붙였다가..
#
#
#     5. Expressions 주의사항
#
#         ![이미지](../이미지/expressions.PNG)

# %% [markdown]
# 2. Directive
#
#     - 개념 : 'v-' 접두사가 있는 특수 속성
#
#     ![이미지](../이미지/v-on.PNG)
#
#
#     - 특징
#
#         - Directive의 속성 값은 단일 JS 표현식이어야 함(v-for, v-on 제외)
#         - **표현식 값이 변경될 때 DOM에 반응적으로 업데이트를 적용**
#
#
#     - Arguments
#
#     ![이미지](../이미지/directive.PNG)
#
#
#     - Modifiers
#
#     ![이미지](../이미지/directive1.PNG)
#
#
#     - built-in Directives(공식문서 찾아보셈)
#
#         - v-text
#
#         - v-show
#
#         - v-if
#
#         ![이미지](../이미지/v-if.PNG)
#
#         - v-for

# %% [markdown]
# #### 2. Dynamically data binding(동적 데이터 바인딩:v-bind)
#
# 1. v-bind
#
#     - 하나 이상의 속성 또는 컴포넌트 데이터를 표현식에 **동적으로 바인딩**
#
#     - 속성 바인딩, 클래스 바인딩, 스타일 바인딩
#
#     1. Attribute(속성) Bindings
#
#     ![이미지](../이미지/속성바인딩.PNG)
#
#     ![이미지](../이미지/속성바인딩1.PNG)
#
#     ![이미지](../이미지/속성바인딩2.PNG)
#
#     - p태그의 속성(title) = 속성값(Hello Vue.js)
#
#     ![이미지](../이미지/속성바인딩3.PNG)
#
#
#     2. Class(클래스) and Style(스타일) Bindings
#
#         - 클래스와 스타일은 모두 속성이므로 v-bind를 사용하여 다른 속성과 마찬가지로 동적으로 문자열 값을 할당할 수 있음
#
#         - 그러나 단순히 문자열 연결을 사용하여 이러한 값을 생성하는 것은 번거롭고 오류가 발생하기 쉬움
#
#         - 그래서 Vue는 클래스 및 스타일과 함께 v-bind를 사용할 때 객체 또는 배열을 활용한 개선 사항을 제공
#
#             - Binding HTML Classes => binding to objects, binding to arrays
#             - Binging Inline Styles => binding to objects, binding to arrays
#
#         1. Binding HTML Classes
#
#             - binding to objects
#
#             ![이미지](../이미지/bindingtoobject.PNG)
#
#             ![이미지](../이미지/bindingtoobject1.PNG)
#
#             ![이미지](../이미지/bindingtoobject2.PNG)
#
#             - binding to arrays
#
#             ![이미지](../이미지/bindingtoarray.PNG)
#
#             ![이미지](../이미지/bindingtoarray1.PNG)
#
#         2. Binging Inline Styles
#
#             - binding to objects
#
#             ![이미지](../이미지/bindingtoobject3.PNG)
#
#             ![이미지](../이미지/bindingtoobject4.PNG)
#
#             - binding to arrays
#
#             ![이미지](../이미지/bindingtoarray2.PNG)
#
#
# v-bind 종합
#
# https://vuejs.org/api/built-in-directives.html#v-bind

# %% [markdown]
# #### 3. Event Handling(v-on)
#
# 1. v-on : DOM 요소에 이벤트 리스너를 연결 및 수신
#
#     ![이미지](../이미지/v-on1.PNG)
#
#     1. Inline handlers
#
#         - Inline handlers는 주로 간단한 상황에 사용
#
#         ![이미지](../이미지/inline%20handlers.PNG)
#
#     2. Method handlers
#
#         - Inline handlers로는 불가능한 대부분의 상황에서 사용
#
#         ![이미지](../이미지/method%20handler.PNG)
#
#     3. Inline handlers에서의 메서드 호출
#
#         ![이미지](../이미지/inline%20메서드%20호출.PNG)
#
#         - 나중에 for문 돌면서 인자값을 추가해줄 때! 사용
#
#
#     4. Inline handlers에서의 event 인자에 접근하기
#
#         ![이미지](../이미지/event접근.PNG)
#
#
# 2. Event Modifiers
#
#     ![이미지](../이미지/event%20modifiers.PNG)
#
#
# 3. Key Modifiers
#
#     ![이미지](../이미지/keymodifiers.PNG)
#
#
# v-on 종합
#
# https://vuejs.org/api/built-in-directives.html#v-on

# %% [markdown]
# #### 4. Form Input Bindings
#
# - form을 처리할 때 사용자가 input에 입력하는 값을 실시간으로 JavaScript 상태에 동기화해야하는 경우(**양방향 바인딩**)
#
# 1. 양방향 바인딩 방법
#
#     1. v-bind와 v-on을 함께 사용
#
#         - v-bind를 사용하여 input 요소의 value 속성 값을 입력 값으로 사용
#
#         - v-on을 사용하여 input 이벤트가 발생할 때마다 input 요소의 value 값을 별도 반응형 변수에 저장하는 핸들러를 호출
#
#         ![이미지](../이미지/v-bind_v-on.PNG)
#
#         ![이미지](../이미지/v-bind_v-on1.PNG)
#
#     2. v-model 사용
#
#         - form input 요소 또는 컴포넌트에서 양방향 바인딩을 만듦
#
#
#
#
#         ![이미지](../이미지/v-mo)
#
#         - v-model을 사용하여 사용자 입력 데이터와 반응형 변수를 실시간 동기화
#
#             - IME가 필요한 언어(한국어, 중국어, 일본어 등)의 경우 v-model이 제대로 업데이트 되지 않음
#
#             - 해당 언어에 대해 올바르게 응답하려면 v-bind와 v-on의 방법을 사용해야함
#
# 2. v-model 활용

# %% [markdown]
# #### 5. Computed Property
#
#
# 1. computed
#
#     - **계산된 속성을 정의**하는 함수(미리 계산된 속성을 사용하여 템플릿에서 표현식을 단순하게 하고 **불필요한 반복 연산을 줄임**)
#
#     - computed 예시 : 할 일이 남았는지 여부에 따라 다른 메시지 출력하기
#
#         ![이미지](../이미지/computed.PNG)
#
#         - **템플릿이 복잡**해지며 todos에 따라 계산을 수행하게 됨
#
#         - 만약 이 계산을 템플릿에 여러 번 사용하는 경우 반복이 발생(비효율적 코드)
#
#         ![이미지](../이미지/computed1.PNG)
#
#         - 이러한 코드에 computed 속성을 적용하여 **미리 값을 계산(cach)**
#
#         - **따라서 템플릿의 복잡성을 줄여 가독성을 늘리고, 생산적인 코드를 작성하기 위해 computed 사용**
#
#     - computed 특징
#
#         - 반환되는 값은 computed ref이며 일반 refs와 유사하게 계산된 결과를 .value로 참조할 수 있음(템플릿에서는 .value 생략 가능)
#
#         - computed 속성은 의존된 반응형 데이터(return 값)를 자동으로 추적
#
#         - 의존하는 데이터가 변경될 때만 재평가
#
#             - restOfTodos의 계산은 todos에 의존하고 있음
#             - 따라서 todos가 변경될 때만 restOfTodos가 업데이트 됨
#
#         - 주의 computed 반환 값은 변경하지 말 것
#
# 2. Methods
#
#     ![이미지](../이미지/computedmethod.PNG)
#
#     - 결국 computed는 메서드의 역할을 하는 건데.. 둘이 무슨 차이가 있음?(접근방식은 실제로 동일)
#
#     - computed 속성은 **의존된 반응형 데이터를 기반으로 캐시(cached)된다**
#
#     - 즉, 의존된 반응형 데이터(return 값)가 변경되지 않는 한 이미 계산된 결과에 대한 여러 참조는 다시 평가할 필요 없이 이전에 계산된 결과를 즉시 반환
#
#         - cache(캐시)
#
#             - 데이터나 결과를 일시적으로 저장해두는 임시 저장소
#             - 이후에 같은 데이터나 결과를 다시 계산하지 않고 빠르게 접근할 수 있도록 함
#
#     - 반면에, method 호출은 다시 렌더링이 발생할 때마다 항상 함수를 실행
#
#     - 따라서 코드가 복잡할 경우 computed가 더 빠른 응답이 가능함
#
#
# 3. computed와 method 정리
#
#     1. computed
#
#         - 의존된 데이터가 변경되면 자동으로 업데이트
#         - 의존하는 데이터에 따라 결과가 바뀌는 **계산된 속성을 만들 때** 유용
#         - 동일한 의존성을 가진 여러 곳에서 사용할 때 계산 결과를 캐싱(임시저장)하여 중복 계산 방지
#
#     2. method
#
#         - 호출해야만 실행됨
#         - 단순히 특정 동작을 수행하는 함수를 정의할 때 사용
#         - 데이터에 의존하는지 여부와 관계없이 항상 동일한 결과를 반환하는 함수
#
#
#     - **무조건 computed만 사용하는 것이 아니라 사용 목적과 상황에 맞게 computed와 method를 적절히 조합하여 사용**

# %% [markdown]
# #### 6. Conditional Rendering
#
# 1. v-if
#
#     - v-else-if, v-else
#     - 표현식 값의 T/F를 기반으로 요소를 조건부로 **렌더링**(렌더링 할지 말지 결정)
#     - 공간조차 없애버린다는 뜻
#
#     - 예시 :
#
#         ![이미지](../이미지/v-if토글.PNG)
#
#     - 여러 요소에 대한 v-if 적용 : **template 요소에 v-if 사용**
#
#         ![이미지](../이미지/v-iftemp.PNG)
#
# 2. v-show
#
#     - 표현식 값의 T/F를 기반으로 요소의 **가시성**을 전환(보여줄지 말지 결정)
#     - 숨겨두기 but, 공간은 남아있음(display: none) => DOM에 남아있음
#
#
# 3. v-if vs v-show
#
#     - v-if
#
#         - 초기 조건이 false인 경우, 아무 작업도 수행하지 않음
#         - 토글 비용이 높음
#
#     - v-show
#
#         - 초기 조건에 관계없이 항상 렌더링
#         - 초기 렌더링 비용이 더 높음
#
#     - 따라서 무언가를 매우 자주 전환해야하는 경우에는 v-show를, 실행 중에 조건이 변경되지 않는 경우에는 v-if를 권장

# %% [markdown]
# #### 7. List Rendering
#
# 1. v-for
#
#     - 소스 데이터(Array, Object, number, string, iterable)를 기반으로 요소 또는 템플릿 블록을 여러 번 렌더링
#
#     1. 배열 반복 예시
#
#         ![이미지](../이미지/v-for0.PNG)
#
#         - 0 / {"name": "Alice", "age":20}
#         - 1 / {"name": "Bella", "age":21}
#
#     2. 객체 반복 예시
#
#         ![이미지](../이미지/v-for.PNG)
#
#         - 0 / name / Cathy
#         - 1 / age / 30
#
#     3. 여러 요소에 대한 v-for 적용
#
#         ![이미지](../이미지/v-for1.PNG)
#
#         - template 요소에 v-for를 사용하여 1개 이상의 요소에 대해 반복 렌더링 할 수 있음
#
#     4. 중첩된 v-for(이중 v-for)
#
#         ![이미지](../이미지/v-for2.PNG)
#
#
# 2. v-for with key
#
#     - 우선순위 A : **반드시 v-for와 key 힘께 작성한다!**(데이터 조작을 쉽게 하기 위해)
#
#     - key는 반드시 각 요소에 대한 고유한 값(id)을 나타낼 수 있는 식별자이어야 함.
#
#     - 주의 : 배열의 index를 v-for의 key로 사용하지 말 것
#
#         - 인덱스는 식별자가 아닌 배열의 항목 위치만 나타내기 때문에 Vue가 DOM을 변경 할 때 (끝이 아닌 위치에 새 항목이 배열에 삽입되면) 여러 컴포넌트 간 데이터 공유 시 문제가 발생
#
#         - 직접 고유한 값을 만들어내는 메서드를 만들거나, 외부 라이브러리 등을 활용하는 등 식별자 역할(id)을 할 수 있는 값을 만들어 사용
#
#     ![이미지](../이미지/v-for%20id.PNG)
#
#
# 3. v-for with v-if
#
#     - 우선순위 A : **v-for와 v-if를 함께 사용하지 않는다!**(v-if가 v-for보다 우선순위가 더 높기 때문)
#
#     - 예시 : v-for과 v-if 문제 상황
#
#         - todo 데이터 중 이미 처리 한(isComplete === true) todo만 출력하기
#
#         ![이미지](../이미지/v-forv-if.PNG)
#         ![이미지](../이미지/v-forv-if2.PNG)
#
#         - v-if가 더 높은 우선순위를 가지므로, v-for의 todo 요소를 v-if에서 사용할 수 없음
#
#         - 방법 1:
#
#             ![이미지](../이미지/v-forv-if1.PNG)
#
#             - **computed를 활용해 필터링 된 목록을 반환하여 반복**하도록 설정
#
#         - 방법 2:
#
#             ![이미지](../이미지/v-forv-if3.PNG)
#
#             - v-for과 template 요소를 사용하여 v-if를 이동

# %% [markdown]
# #### 8. Watchers
#
# - watch : **반응형 데이터를 감시**하고, **감시하는 데이터가 변경되면 콜백함수를 호출**(computed 예시와 비슷)
#
# - 예시 1 : 감시하는 변수에 변화가 생겼을 때 기본 동작 확인하기
#
#     ![이미지](../이미지/watch.PNG)
#
#     - 특정 변수를 감시하고 있음. 그런데 감시변수에 특정 변화가 일어나면 '바뀐 후의 값'과 '바뀌기 전에 값'에 대해 지정해준 작업을 수행함
#
#     ![이미지](../이미지/watch2.PNG)
#
# - 예시 2 : 감시하는 변수에 변화가 생겼을 때 연관 데이터 업데이트하기(ex 글자수 세기)
#
#     ![이미지](../이미지/watch1.PNG)
#
#     ![이미지](../이미지/watch3.PNG)
#
#
# ![이미지](../이미지/computed_watchers.PNG)
#
# - computed는 특정 작업에 대한 반환 값 하나를 반환해줌!

# %% [markdown]
# #### 9. Lifecycle Hooks(생애주기 걸다)
#
# - Vue 인스턴스의 생애주기 동안 특정 시점에 실행되는 함수
#
# - 개발자가 특정 단계에서 의도하는 로직이 실행될 수 있도록 함
#
# ![이미지](../이미지/onmounted.PNG)
#
# ![이미지](../이미지/onupdated.PNG)
#
# ![이미지](../이미지/onupdated1.PNG)
#
# ![이미지](../이미지/lifecycle%20hook.PNG)

# %% [markdown]
# #### 10. 참고
#
# 1. v-for와 배열 : 배열 변경 감지
#
# ![이미지](../이미지/v-for%20참고.PNG)
#
#
# 2. v-for와 배열 : "필터링/정렬 결과 표시"
#
#     - 원본 데이터를 수정하거나 교체하지 않고 필터링 되거나 정렬된 결과를 표시
#
#         1. computed 활용
#
#         ![이미지](../이미지/v-for%20배열.PNG)
#
#         2. method 활용(computed가 불가능한 중첩된 v-for의 경우)
#
#         ![이미지](../이미지/v-for%20배열.PNG)
