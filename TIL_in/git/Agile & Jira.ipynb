# %% [markdown]
# # Agile & Jira

# %% [markdown]
# ## 1. Agile 개발론 소개

# %% [markdown]
# #### 1. Agile 정의
#
# ![이미지](../이미지/애자일.PNG)
#
# - 사전적 의미 : 신속한, 날렵한, 기민한
#
# - SW 방법론 내포적 의미 : 짧은 주기의 개발 단위를 반복하여 프로젝트를 완성해 가는 것
#
# - 어떻게 반복하라는 것인가? : 스프린트(sprint) 단위로 디자인 -> 개발 -> 테스트 반복
#
#
# #### 2. Agile 방법론 특징
#
# ![이미지](../이미지/워터폴vs애자일.PNG)
#
# - 고객과 개발자의 지속적인 소통으로 변화하는 요구 사항을 신속하게 반영가능
#
# - 개인 보다는 팀의 목적을 우선시하며, 고객의 의견을 가장 높은 가치로 둔다
#
# - 팀원들의 주기적인 회의 및 제품 시현을 통해 잠재적인 버그 수정과 미흡한 기능 추가 가능
#
# - 프로젝트를 진행하면서 고객으로부터 즉각적인 피드백을 통한 수정, 보완 가능
#
# - 팀원들의 주도적이며 자발적인 개발문화로 프로그램 전체의 품질 향상에 기여 가능
#
#
#
# #### 3. 워터폴(폭포수) 개발론
#
# ![이미지](../이미지/워터폴.webp)
#
# - 각 작업이 마치 폭포수가 내려가듯이 작업절차 진행
#
# - 한 단계가 마무리 되기 전 다음 단계로 진행이 되지 못함
#
# - 속도가 느리고 유연하지 못하다는 단점을 지님
#
# - 요구 사항이 바뀌거나 수정하려면 다시 맨 처음부터 수정해야하는 불편함이 존재
#
# #### 4. 워터폴(폭포수) 개발론 vs Agile 개발론
#
# ![이미지](../이미지/워터폴vs애자일2.PNG)
#
# ![이미지](../이미지/워터폴vs애자일1.PNG)

# %% [markdown]
# ## 2. Jira 프로젝트 구조

# %% [markdown]
# #### 1. Jira
#
# 1. Jira 개념
#
#     - Issue Tracking Tool(PM)
#
#     - **Jira == PMS(project management system)** : 프로젝트의 정량적인 성과 및 진행 지표를 체계적으로 관리하기 위한 것
#
#     - 현재 우리 프로젝트의 위치가 어딘가? : 주제, 방향성, 진행상황, 리스크 관리(시작날짜, 만료기한)
#
#     - Atlassian에서 제공하는 **이슈 관리 소프트웨어**인 Jira는 이슈와   스프린트, 스크럼 보드 제공 등 이슈로 정의할 수 있는 개발 항목들(기능,     작업 단위, 버그 등)을 관리함
#
#
# #### 2. Jira 프로젝트 구조
#
# ![이미지](../이미지/에픽스토리등.PNG)
#
# 1. 에픽(Epic)
#
#     - 완료까지 여러 번의 스프린트가 요구되는 큰 업무 단위(최상위 수준의 기능/작업 단위)
#     - 여러 개의 스토리로 나눌 수 있는 작업구조
#     - 예시 : 회원 관리, 유저 인증 등
#
# 2. 스토리(Story)
#
#     - 사용자 관점에서 작성된 요구사항(Epic에 대한 하위 Level 수준의 기능/작업 단위)
#     - (사용자는) [목적]을 위해 [행위]를 할 수 있다.
#     - 예시 : 서비스 사용을 위해 회원가입을 할 수 있다. 사용자 인증을 위해 이메일 인증을 할 수 있다.
#
# 3. 작업(Task)
#
#     - 스토리를 완료하기 위해 개발자가 수행하는 단위 작업
#     - 예시 : 회원가입 폼 구현(FE), 사용자 확인을 위한 API 구현(BE)
#
# 4. 버그(Bug)
#
#     - 프로젝트 개발/검증 중 발견된 버그
#     - 예시 : 상품 검색 시 특정 상품이 조회되지 않은 문제
#
# 4. 스프린트(Sprint)
#
#     ![이미지](../이미지/sprint.PNG)
#
#     - 스프린트는 팀이 일정량의 작업을 완료하는 시간이 정해진 짧은 기간입니다.
#
#
#
# #### 3. Jira 특정 기능
#
# 1. MVP(Minimum Viable Product) : 최소 기능 제품
# - 고객이 원하는 제품의 최소한을 정의
#     - 최소 비용, 핵심 기능 만을 담은 제품
#     - 시간과 비용 절감 측면에서 효율적
#     - 사업 리스크 최소화 : 실패하더라도 괜차나!
#
#
# 2. 스프린트(Sprint)
# - 팀의 일정량의 작업을 완료하기 위해 정해진 짧은 기간
# - 스프린트 계획 회의 - 스프린트 기간 동안 해야할 일들을 정리하고 달성하기 위한 방법 회의
#
#
# 3. 스크럼(Scrum)
# - 정해진 스프린트 내에 실제 행해져야 하는 개발 업부
# - 제품 백로그 작성 : 고객, 프로젝트 이해관계자 의견 취합, 업무 우선 순위 매기는 작업
# - 스프린트 백로그 작성 : 스프린트 내에 각 팀원들이 해야할 업무의 리스트 만드는 작업
# - 데일리 스크럼 : 매일 진행한 업무를 보고하고 공유
# - 개발 및 테스트 : 실제 맡은 영역 개발, 테스트
# - 스프린트 리뷰 및 회고 : 장 단점 분석, 더 나은 방향으로 개선
#
#
# 4. 테스트 주도적 개발
# - 실제 필요한 기능만 만들고 그 기능이 제대로 동작하는지 코드 기반 테스트
# - 잘 동작 => 코드 리팩토링 및 모듈화
#
#
# 5. 데브옵스
# - 개발 + 운영
# - 새로운 소프트웨어 기능 개선, 버그 수정시 바로 배포함 => 빠른 피드백 가능
# - 지속적 통합 및 연속 배포(CI/CD) 구축
#
#
#
#
#
# #### 4. DevOps(개발 + 운영)
#
# - 반복적인 작업들을 Tool을 이용해서 자동화
#
# - 팀원 모두가 알고 있는 하나의 공유된 지표가 필요
#
# - 장애나 이슈가 있을 때 혼자만 알지 말고 팀원들과 공유 필요
# 는 데 높은 활용성을 제공함
#
#     - Jira 시스템을 활용하는 조직마다 나름의 기준을 가지고 사용하는데   Jira에서 추구하는 **애자일 프로세스**에 대체로 기반하고 있으며,   **이슈의 유형**은 보통 아래와 같은 기준으로 구분하여 사용함.
#
# 2. 이슈 유형
#
#     ![이미지](../이미지/에픽스토리테스크.webp)
#
#     - Epic : 최상위 수준의 기능/작업 단위(프로젝트 전반 또느 여러 Sprint에 걸쳐 진행할 정도의 범위) / 회원 관리, 로그인 관리
#
#     - Story : Epic에 대한 하위 Level 수준의 기능/작업 단위 / 회원가입, 회원정보 수정, 회원 탈퇴, 로그인, 비밀번호 찾기
#
#     - Bug : 프로젝트 개발/검증 중 발견된 버그 / 상품 검색 시 특정 상품이 조회되지 않은 문제
#
#     - Task : 개발에 직접 해당되지는 않으나 Sprint 안에 포함하여 해야할 일 / ERD 작성, 테스트 케이스 작성
#
#     - Sub-task : 위 issue들과 관련하여 세부 단위 작업 등이 필요할 때 등록
#
# 3. 특정 기능
#
#     1. 보드(board)
#
#         - 스크럼 보드 : 스프린트(Sprint) 또는 팀이 정해진 양의 작업을 완료하기 위해 노력하는 시간이 정해진 기간에 작업하는 팀에 적합함
#
#             ![이미지](../이미지/스크럼보드.png)
#
#         - 칸반 보드 : 작업의 흐름을 관리하는 것을 주 목표로 하는 팀에 유용함
#
#             ![이미지](../이미지/칸반보드.png)
#
#     2. 일정(timeline) : 계획보기
#
#         ![이미지](../이미지/타임라인.png)
#
#         ![이미지](../이미지/타임라인1.png)
#
#     3. 인사이트
#
#         - 인사이트는 Jira 보드 및 프로젝트 데이터를 기반으로 팀의 진행률 기록을 집계하여 보여줌
#
#         - 인사이트는 팀이 현재 컨텍스트를 벗어나지 않고도 데이터 기반 결정을 내리는데 도움이 됨
#
#     4. 통합
#
# - Sprint :
#
#
# - https://www.atlassian.com/ko/software/jira/guides/getting-started/introduction#what-is-jira-software
#
#
# #### 5. 애자일 프레임 워크
#
# 1. MVP(Minimum Viable Product) : 최소 기능 제품
# - 고객이 원하는 제품의 최소한을 정의
#     - 최소 비용, 핵심 기능 만을 담은 제품
#     - 시간과 비용 절감 측면에서 효율적
#     - 사업 리스크 최소화 : 실패하더라도 괜차나!
#
#
# 2. 스프린트(Sprint)
# - 팀의 일정량의 작업을 완료하기 위해 정해진 짧은 기간
# - 스프린트 계획 회의 - 스프린트 기간 동안 해야할 일들을 정리하고 달성하기 위한 방법 회의
#
#
# 3. 스크럼(Scrum)
# - 정해진 스프린트 내에 실제 행해져야 하는 개발 업부
# - 제품 백로그 작성 : 고객, 프로젝트 이해관계자 의견 취합, 업무 우선 순위 매기는 작업
# - 스프린트 백로그 작성 : 스프린트 내에 각 팀원들이 해야할 업무의 리스트 만드는 작업
# - 데일리 스크럼 : 매일 진행한 업무를 보고하고 공유
# - 개발 및 테스트 : 실제 맡은 영역 개발, 테스트
# - 스프린트 리뷰 및 회고 : 장 단점 분석, 더 나은 방향으로 개선
#
#
# 4. 테스트 주도적 개발
# - 실제 필요한 기능만 만들고 그 기능이 제대로 동작하는지 코드 기반 테스트
# - 잘 동작 => 코드 리팩토링 및 모듈화
#
#
# 5. 데브옵스
# - 개발 + 운영
# - 새로운 소프트웨어 기능 개선, 버그 수정시 바로 배포함 => 빠른 피드백 가능
# - 지속적 통합 및 연속 배포(CI/CD) 구축

# %% [markdown]
# ![이미지](../이미지/프로젝트%20발표평가(팀간).PNG)
